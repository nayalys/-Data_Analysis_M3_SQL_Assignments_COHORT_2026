# %% [markdown]
# # Workflow Practice
#
# In this notebook, you’ll practice connecting to a SQLite database, creating tables from CSV files using Pandas, and writing SQL queries to explore the data.
#
# The dataset comes from the [Bike Store Sample Database](https://www.kaggle.com/datasets/dillonmyrick/bike-store-sample-database) by Dillon Myrick. It models a fictional bike retailer with multiple stores, products, customers, and staff. Each table connects to others using foreign keys such as `customer_id`, `store_id`, and `product_id`.
#
# You’ll:
# - Connect to a local SQLite database
# - Create tables using `pandas.to_sql()`
# - Write and test SQL queries using `pd.read_sql()`
#
# All of your work will take place directly in this notebook. Each question prompt is written below as a Markdown cell, followed by an empty code cell for you to write your query.

# %% [markdown]
# ## Step 1: Connect to the Database
#
# Run the following cell to connect to (or create) a SQLite database called `bike_store.db`.
# If the file doesn’t exist yet, SQLite will automatically create it.

# %%
import sqlite3
import pandas as pd

# %%
connection = sqlite3.connect("bike_store.db")
connection

# %% [markdown]
# ## Step 2: Create Tables from CSV Files
#
# The `data/` folder contains one CSV file per table.
# Use `pandas.read_csv()` and `DataFrame.to_sql()` to load each file into your database.
#
# You only need to do this once.
# After that, you’ll be able to run queries against your newly created tables.

# %%
# Example for one file
customers = pd.read_csv("data/customers.csv")
customers.to_sql("customers", connection, if_exists="replace", index=False)
# Out:
# 1445

# %%
# Repeat for all other files in the data folder, or use a loop.
# Example for one file
customers = pd.read_csv("data/brands.csv")
customers.to_sql("brands", connection, if_exists="replace", index=False)
# Out:
# 3

# %%
# Categories Table
categories = pd.read_csv("data/categories.csv")
categories.to_sql("categories", connection, if_exists="replace", index=False)
# Out:
# 7

# %%
# Order_items Table
order_items = pd.read_csv("data/order_items.csv")
order_items.to_sql("order_items", connection, if_exists="replace", index=False)
# Out:
# 4722

# %%
# Orders Table
orders = pd.read_csv("data/orders.csv")
orders.to_sql("orders", connection, if_exists="replace", index=False)
# Out:
# 3

# %%
# Products Table
products = pd.read_csv("data/products.csv")
products.to_sql("products", connection, if_exists="replace", index=False)
# Out:
# 321

# %%
# Staffs Table
staffs = pd.read_csv("data/staffs.csv")
staffs.to_sql("staffs", connection, if_exists="replace", index=False)
# Out:
# 10

# %%
# Stocks Table
stocks = pd.read_csv("data/stocks.csv")
stocks.to_sql("stocks", connection, if_exists="replace", index=False)
# Out:
# 939

# %%
# Stores Table
stores = pd.read_csv("data/stores.csv")
stores.to_sql("stores", connection, if_exists="replace", index=False)
# Out:
# 3

# %% [markdown]
# ### Verify Your Tables
#
# Run a query to make sure your tables were created successfully.

# %%
pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", connection)
# Out:
#           name
# 0    customers
# 1       brands
# 2   categories
# 3  order_items
# 4       orders
# 5     products
# 6       staffs
# 7       stocks
# 8       stores

# %%
pd.read_sql("SELECT * FROM products ;", connection)
# Out:
#      product_id                          product_name  brand_id  category_id  \
# 0             1                       Trek 820 - 2016         9            6
# 1             2    Ritchey Timberwolf Frameset - 2016         5            6
# 2             3       Surly Wednesday Frameset - 2016         8            6
# 3             4              Trek Fuel EX 8 29 - 2016         9            6
# 4             5          Heller Shagamaw Frame - 2016         3            6
# ..          ...                                   ...       ...          ...
# 316         317          Trek Checkpoint ALR 5 - 2019         9            7
# 317         318  Trek Checkpoint ALR 5 Women's - 2019         9            7
# 318         319   Trek Checkpoint SL 5 Women's - 2019         9            7
# 319         320           Trek Checkpoint SL 6 - 2019         9            7
# 320         321   Trek Checkpoint ALR Frameset - 2019         9            7
#
#      model_year  list_price
# 0          2016      379.99
# 1          2016      749.99
# 2          2016      999.99
# 3          2016     2899.99
# 4          2016     1320.99
# ..          ...         ...
# 316        2019     1999.99
# 317        2019     1999.99
# 318        2019     2799.99
# 319        2019     3799.99
# 320        2019     3199.99
#
# [321 rows x 6 columns]

# %% [markdown]
# ## Step 3: Test a Simple Query
#
# Before starting the exercises, confirm your connection and tables are working by previewing the first few rows of the `customers` table.

# %%
pd.read_sql("SELECT discount from order_items", connection)
# Out:
#       discount
# 0         0.20
# 1         0.07
# 2         0.05
# 3         0.05
# 4         0.20
# ...        ...
# 4717      0.07
# 4718      0.20
# 4719      0.20
# 4720      0.07
# 4721      0.20
#
# [4722 rows x 1 columns]

# %% [markdown]
# ### Q1. List all customers and their cities.
#
# Return the first name, last name, and city of each customer. Sort alphabetically by last name and then by first name.

# %%
# Your query here
query1 = """ select first_name,last_name,city from customers order by last_name
"""
pd.read_sql(query1, connection)
# Out:
#       first_name  last_name                 city
# 0         Jamika    Acevedo           Ozone Park
# 1          Penny    Acevedo         Ballston Spa
# 2          Ester    Acevedo          San Lorenzo
# 3          Shery     Acosta     Saratoga Springs
# 4       Bettyann     Acosta            Lancaster
# ...          ...        ...                  ...
# 1440        Edda      Young      North Tonawanda
# 1441      Jasmin      Young              Helotes
# 1442       Jayme     Zamora  Springfield Gardens
# 1443  Alexandria     Zamora          Schenectady
# 1444       Ollie  Zimmerman              Anaheim
#
# [1445 rows x 3 columns]

# %% [markdown]
# ### Q2. Show all products and their prices.
#
# Display each product name along with its list price. Sort by price in descending order.

# %%
# Your query here
query2 = """ select product_name, list_price from products order by list_price desc
"""
pd.read_sql(query2, connection)
# Out:
#                                product_name  list_price
# 0             Trek Domane SLR 9 Disc - 2018    11999.99
# 1             Trek Domane SLR 8 Disc - 2018     7499.99
# 2          Trek Silque SLR 8 Women's - 2017     6499.99
# 3            Trek Domane SL Frameset - 2018     6499.99
# 4    Trek Domane SL Frameset Women's - 2018     6499.99
# ..                                      ...         ...
# 316                    Trek Kickster - 2018      159.99
# 317         Trek Boy's Kickster - 2015/2017      149.99
# 318             Trek Girl's Kickster - 2017      149.99
# 319          Sun Bicycles Lil Kitt'n - 2017      109.99
# 320  Strider Classic 12 Balance Bike - 2018       89.99
#
# [321 rows x 2 columns]

# %% [markdown]
# ### Q3. Find all customers from California.
#
# Return first name, last name, city, and state for all customers whose state is 'CA'. Sort alphabetically by last name.

# %%
# Your query here
query3 = """ select first_name,last_name, city, state from customers where state = 'CA' order by last_name
"""
pd.read_sql(query3, connection)
# Out:
#     first_name  last_name                    city state
# 0        Ester    Acevedo             San Lorenzo    CA
# 1       Jamaal     Albert                Torrance    CA
# 2        Sindy   Anderson                  Pomona    CA
# 3        Twana     Arnold                 Anaheim    CA
# 4       Selene     Austin                  Duarte    CA
# ..         ...        ...                     ...   ...
# 279     Darren       Witt               Coachella    CA
# 280       Lucy      Woods  Palos Verdes Peninsula    CA
# 281       Joel       Wynn               San Diego    CA
# 282      Yvone      Yates               San Pablo    CA
# 283      Ollie  Zimmerman                 Anaheim    CA
#
# [284 rows x 4 columns]

# %% [markdown]
# ### Q4. Count how many products are in each category.
#
# Return the category name and the number of products in that category. Sort from the highest count to the lowest.

# %%
# Your query here
query4 = """ select
                     ca.category_name,
                     count(p.product_id) total_product 
             from products p 
             join categories ca on ca.category_id = p.category_id
             group by ca.category_name
             order by total_product desc
"""
pd.read_sql(query4, connection)
# Out:
#          category_name  total_product
# 0    Cruisers Bicycles             78
# 1           Road Bikes             60
# 2       Mountain Bikes             60
# 3    Children Bicycles             59
# 4     Comfort Bicycles             30
# 5       Electric Bikes             24
# 6  Cyclocross Bicycles             10

# %% [markdown]
# ### Q5. Find all orders placed in 2018.
#
# List the order ID, order date, and customer ID for orders made during the year 2018. Sort by order date.

# %%
# Your query here
query5 = """ select order_id, order_date, customer_id 
             from orders where order_date like '2018%'
             order by order_date """
pd.read_sql(query5, connection)
# Out:
#      order_id  order_date  customer_id
# 0        1324  2018-01-01          862
# 1        1325  2018-01-01           68
# 2        1326  2018-01-01          567
# 3        1327  2018-01-02         1026
# 4        1328  2018-01-02         1083
# ..        ...         ...          ...
# 287      1611  2018-09-06            6
# 288      1612  2018-10-21            3
# 289      1613  2018-11-18            1
# 290      1614  2018-11-28          135
# 291      1615  2018-12-28          136
#
# [292 rows x 3 columns]

# %%
pd.read_sql("SELECT * FROM order_items ;", connection)
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount
# 0            1        1          20         1      599.99      0.20
# 1            1        2           8         2     1799.99      0.07
# 2            1        3          10         2     1549.00      0.05
# 3            1        4          16         2      599.99      0.05
# 4            1        5           4         1     2899.99      0.20
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2     2299.99      0.07
# 4718      1614        3         213         2      269.99      0.20
# 4719      1615        1         197         2     2299.99      0.20
# 4720      1615        2         214         1      899.99      0.07
# 4721      1615        3         182         1     2499.99      0.20
#
# [4722 rows x 6 columns]

# %% [markdown]
# ### Q6. Show each order with its total number of items.
#
# Join the `orders` and `order_items` tables. Group by order ID and return the number of items per order.

# %%
# Your query here
query6 = """ select  o.order_id, sum(oi.quantity) number_of_items from orders o
             join order_items oi on  o.order_id = oi.order_id
             group by o.order_id
"""
pd.read_sql(query6, connection)
# Out:
#       order_id  number_of_items
# 0            1                8
# 1            2                3
# 2            3                2
# 3            4                2
# 4            5                4
# ...        ...              ...
# 1610      1611                4
# 1611      1612                8
# 1612      1613                3
# 1613      1614                5
# 1614      1615                4
#
# [1615 rows x 2 columns]

# %% [markdown]
# ### Q7. List total revenue per store.
#
# Revenue = quantity * list_price * (1 - discount). Join `orders`, `order_items`, and `stores`, group by store name, and return total revenue.

# %%
# Your query here
query7 = """ select st.store_name, st.store_id,sum(oi.quantity * oi.list_price * (1 - oi.discount)) Total_Revenue
             from orders o
             join order_items oi on oi.order_id = o.order_id
             join stores st on st.store_id = o.store_id
             group by store_name
             
"""
pd.read_sql(query7, connection)
# Out:
#          store_name  store_id  Total_Revenue
# 0     Baldwin Bikes         2   5.215751e+06
# 1     Rowlett Bikes         3   8.675422e+05
# 2  Santa Cruz Bikes         1   1.605823e+06

# %% [markdown]
# ### Q8. Find the top 5 customers who spent the most overall.
#
# Join `customers`, `orders`, and `order_items`. Sum the total spending per customer and return the top five spenders.

# %%
# Your query here
query8 = """ select  
                    concat(cu.first_name,' ',cu.last_name) Customer_Name,
                    sum(oi.quantity * oi.list_price * (1-oi.discount)) Total_Spend                     
            from orders o
            join order_items oi on o.order_id = oi.order_id
            join customers cu on o.customer_id =cu.customer_id
            group by o.order_id
            order by Total_Spend desc limit 5
"""
pd.read_sql(query8, connection)
# Out:
#     Customer_Name  Total_Spend
# 0  Pamelia Newman   29147.0264
# 1   Melanie Hayes   27050.7182
# 2     Abby Gamble   25574.9555
# 3  Sharyn Hopkins   25365.4344
# 4    Shena Carter   24890.6244

# %% [markdown]
# ### Q9. Show the best-selling product in each category.
#
# Join `products`, `order_items`, and `categories`. For each category, identify the product with the highest total quantity sold.

# %%
# Your query here
query9 = """ select p.product_name Product_Name, cat.category_name Category_Name, sum(oi.quantity) Total_Sold 
             from order_items oi
             join products p on  oi.product_id = p.product_id
             join categories cat on p.category_id = cat.category_id
             group by cat.category_name
             order by Total_Sold desc 
"""
pd.read_sql(query9, connection)
# Out:
#                                      Product_Name        Category_Name  \
# 0  Electra Townie Original 7D EQ - Women's - 2016    Cruisers Bicycles
# 1           Trek Remedy 29 Carbon Frameset - 2016       Mountain Bikes
# 2   Electra Girl's Hawaii 1 (16-inch) - 2015/2016    Children Bicycles
# 3            Electra Townie Original 7D EQ - 2016     Comfort Bicycles
# 4                   Trek Domane SLR 6 Disc - 2017           Road Bikes
# 5                          Surly Straggler - 2016  Cyclocross Bicycles
# 6                            Trek Conduit+ - 2016       Electric Bikes
#
#    Total_Sold
# 0        2063
# 1        1755
# 2        1179
# 3         813
# 4         559
# 5         394
# 6         315

# %%
# pd.read_sql("SELECT * FROM order_items LIMIT 5;", connection)
pd.read_sql("SELECT * FROM staffs LIMIT 5;", connection)
# Out:
#    staff_id first_name last_name                       email           phone  \
# 0         1    Fabiola   Jackson  fabiola.jackson@bikes.shop  (831) 555-5554
# 1         2     Mireya  Copeland  mireya.copeland@bikes.shop  (831) 555-5555
# 2         3      Genna   Serrano    genna.serrano@bikes.shop  (831) 555-5556
# 3         4     Virgie   Wiggins   virgie.wiggins@bikes.shop  (831) 555-5557
# 4         5   Jannette     David   jannette.david@bikes.shop  (516) 379-4444
#
#    active  store_id  manager_id
# 0       1         1         NaN
# 1       1         1         1.0
# 2       1         1         2.0
# 3       1         1         2.0
# 4       1         2         1.0

# %% [markdown]
# ### Q10. Identify the employees (staff) who processed the most orders.
#
# Join `staffs` and `orders`. Count the number of orders handled by each staff member and return the results sorted by highest total.

# %%
# Your query here
query10 = """ select concat(stf.first_name,' ',stf.last_name) Staff_Name,stf.staff_id Staff_Id,count(o.order_id) Handled_Orders
              from orders o
              join staffs stf on o.staff_id = stf.staff_id
              group by stf.staff_id, Staff_Name
              order by Handled_Orders desc
"""
pd.read_sql(query10, connection)
# Out:
#         Staff_Name  Staff_Id  Handled_Orders
# 0  Marcelene Boyer         6             553
# 1    Venita Daniel         7             540
# 2    Genna Serrano         3             184
# 3  Mireya Copeland         2             164
# 4      Kali Vargas         8              88
# 5    Layla Terrell         9              86
